# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

def load_image(image_path):

    return cv2.imread(image_path, cv2.IMREAD_COLOR)

def convert_to_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

def segment_image(image, patch_size=100):
    h, w = image.shape
    patches = []
    for y in range(0, h, patch_size):
        for x in range(0, w, patch_size):
            patch = image[y:y+patch_size, x:x+patch_size]  
            patches.append((x, y, patch))  
    return patches

def binarize_patches(patches):
    binarized_patches = []
    for x, y, patch in patches:
        binarized_patch = cv2.adaptiveThreshold(patch, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                                cv2.THRESH_BINARY, 21, 6)  
        binarized_patches.append((x, y, binarized_patch))
    return binarized_patches

def reconstruct_image(patches, original_shape):
    h, w = original_shape
    reconstructed = np.ones((h, w), dtype=np.uint8) * 255  
    for x, y, patch in patches:
        reconstructed[y:y+patch.shape[0], x:x+patch.shape[1]] = patch  
    return reconstructed

def remove_background_noise(image, min_size=30):
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(255 - image, connectivity=8)
    cleaned = np.ones_like(image) * 255  
    for i in range(1, num_labels): 
        if stats[i, cv2.CC_STAT_AREA] > min_size:
            cleaned[labels == i] = 0  
    return cleaned

def enforce_white_background(image):
    background = cv2.GaussianBlur(image, (25, 25), 0)  
    enhanced = cv2.addWeighted(image, 1.5, background, -0.5, 0)  
    return cv2.threshold(enhanced, 200, 255, cv2.THRESH_BINARY)[1]  

def save_image(image, input_path, output_folder):
    filename = os.path.basename(input_path)  
    output_path = os.path.join(output_folder, filename)  
    os.makedirs(output_folder, exist_ok=True)  
    cv2.imwrite(output_path, image, [cv2.IMWRITE_PNG_COMPRESSION, 0])  
    return output_path

def process_all_images(input_root_folder, output_root_folder):
    for root, _, files in os.walk(input_root_folder):
        relative_path = os.path.relpath(root, input_root_folder)
        output_folder = os.path.join(output_root_folder, relative_path)
        os.makedirs(output_folder, exist_ok=True)  

        png_files = [file for file in files if file.lower().endswith(".png")]
        if not png_files:
            print(f"No PNG images found in {root}")
            continue

        for file in png_files:
            input_image_path = os.path.join(root, file)

            image = load_image(input_image_path)
            gray_image = convert_to_grayscale(image)
            image_patches = segment_image(gray_image, patch_size=100)
            binarized_patches = binarize_patches(image_patches)
            binarized_image = reconstruct_image(binarized_patches, gray_image.shape)
            cleaned_background = remove_background_noise(binarized_image)
            final_image = enforce_white_background(cleaned_background)

            save_image(final_image, input_image_path, output_folder)
            print(f"Processed: {input_image_path}")

# %%
input_folder = "img"  
output_folder = "output_2"
process_all_images(input_folder, output_folder)


#print(f"Processing complete. All images saved in: {output_folder}")
# Out:
# No PNG images found in img
# Processed: img\RC04844\page_1.png
# Processed: img\RC04844\page_2.png
# Processed: img\RC04844\page_3.png
# Processed: img\RC04844\page_4.png
# Processed: img\RC04845\page_1.png
# Processed: img\RC04846\page_1.png
# Processed: img\RC04846\page_2.png
# Processed: img\RC04846\page_3.png
# Processed: img\RC04847\page_2.png
# Processed: img\RC04848\page_2.png
# Processed: img\RC04849\page_1.png
# Processed: img\RC04850\page_1.png
# Processed: img\RC04851\page_1.png
# Processed: img\RC04852\page_1.png
# Processed: img\RC04852\page_2.png
# Processed: img\RC04853\page_2.png
# Processed: img\RC04854\page_2.png
# Processed: img\RC04855\page_2.png
# Processed: img\RC04856\page_2.png
# Processed: img\RC04857\page_2.png
# Processed: img\RC04866\page_2.png
# Processed: img\RC04866\page_3.png
# Processed: img\RC04867\page_2.png
# Processed: img\RC04868\page_1.png
# Processed: img\RC04868\page_2.png
# Processed: img\RC04868\page_3.png
# Processed: img\RC04868\page_4.png
# Processed: img\RC04869\page_2.png
# Processed: img\RC04870\page_1.png
# Processed: img\RC04870\page_2.png
# Processed: img\RC04871\page_2.png
# Processed: img\RC04872\page_1.png
# Processed: img\RC04873\page_1.png
# Processed: img\RC04874\page_1.png
# Processed: img\RC04874\page_2.png
# Processed: img\RC04875\page_2.png
# Processed: img\RC04876\page_1.png
# Processed: img\RC04876\page_2.png
# Processed: img\RC04877\page_2.png
# Processed: img\RC04878\page_1.png
# Processed: img\RC04879\page_1.png
# Processed: img\RC04880\page_1.png
# Processed: img\RC04880\page_2.png
# Processed: img\RC04880\page_3.png
# Processed: img\RC04880\page_4.png
# Processed: img\RC04881\page_2.png
# Processed: img\RC04882\page_2.png
# Processed: img\RC04883\page_2.png
# Processed: img\RC04884\page_1.png
# Processed: img\RC04884\page_3.png
# Processed: img\RC04885\page_2.png
# Processed: img\RC04886\page_1.png
# Processed: img\RC04886\page_2.png
# Processed: img\RC04887\page_2.png
# Processed: img\RC04888\page_1.png
# Processed: img\RC04888\page_3.png
# Processed: img\RC04889\page_1.png
# Processed: img\RC04890\page_1.png
# Processed: img\RC04890\page_2.png
# Processed: img\RC04890\page_3.png
# Processed: img\RC04890\page_4.png
# Processed: img\RC04891\page_2.png
# Processed: img\RC04892\page_1.png
# Processed: img\RC04892\page_2.png
# Processed: img\RC04893\page_1.png
# Processed: img\RC04894\page_1.png
# Processed: img\RC04894\page_2.png
# Processed: img\RC04894\page_3.png
# Processed: img\RC04894\page_4.png
# Processed: img\RC04895\page_1.png
# Processed: img\RC04896\page_1.png
# Processed: img\RC04896\page_2.png
# Processed: img\RC04896\page_3.png
# Processed: img\RC04896\page_4.png
# Processed: img\RC04897\page_1.png
# Processed: img\RC04898\page_1.png
# Processed: img\RC04898\page_2.png
# Processed: img\RC04899\page_2.png
# Processed: img\RC04900\page_1.png
# Processed: img\RC04900\page_2.png
# Processed: img\RC04901\page_1.png
# Processed: img\RC04902\page_1.png
# Processed: img\RC04902\page_2.png
# Processed: img\RC04903\page_1.png
# Processed: img\RC04904\page_1.png
# Processed: img\RC04904\page_2.png
# Processed: img\RC04905\page_1.png
# Processed: img\RC04906\page_1.png
# Processed: img\RC04906\page_2.png
# Processed: img\RC04907\page_1.png
# Processed: img\RC04908\page_1.png
# Processed: img\RC04909\page_1.png
# Processed: img\RC04910\page_1.png
# Processed: img\RC04910\page_2.png
# Processed: img\RC04911\page_1.png
# Processed: img\RC04912\page_1.png
# Processed: img\RC04912\page_2.png
# Processed: img\RC04912\page_3.png
# Processed: img\RC04912\page_4.png
# Processed: img\RC04913\page_1.png
# Processed: img\RC04914\page_1.png
# Processed: img\RC04914\page_2.png
# Processed: img\RC04915\page_1.png
# Processed: img\RC04916\page_1.png
# Processed: img\RC04917\page_1.png
# Processed: img\RC04918\page_1.png
# Processed: img\RC04919\page_1.png
# Processed: img\RC04919\page_2.png
# Processed: img\RC04920\page_1.png
# Processed: img\RC04920\page_2.png
# Processed: img\RC04920\page_3.png
# Processed: img\RC04920\page_4.png
# Processed: img\RC04921\page_1.png
# Processed: img\RC04922\page_1.png
# Processed: img\RC04922\page_2.png
# Processed: img\RC04923\page_1.png
# Processed: img\RC04935\page_1.png
# Processed: img\RC04935\page_2.png
# Processed: img\RC04936\page_1.png
# Processed: img\RC04936\page_2.png
# Processed: img\RC04937\page_1.png
# Processed: img\RC04937\page_2.png
# Processed: img\RC04937\page_3.png
# Processed: img\RC04937\page_4.png
# Processed: img\RC04937\page_5.png
# Processed: img\RC04937\page_6.png
# Processed: img\RC04938\page_2.png
# Processed: img\RC04939\page_1.png
# Processed: img\RC04939\page_2.png
# Processed: img\RC04939\page_3.png
# Processed: img\RC04939\page_4.png
# Processed: img\RC04940\page_1.png
# Processed: img\RC04940\page_2.png
# Processed: img\RC04941\page_1.png
# Processed: img\RC04941\page_2.png
# Processed: img\RC04941\page_3.png
# Processed: img\RC04941\page_4.png
# Processed: img\RC04941\page_5.png
# Processed: img\RC04941\page_6.png
# Processed: img\RC04942\page_1.png
# Processed: img\RC04942\page_2.png
# Processed: img\RC04943\page_1.png
# Processed: img\RC04943\page_2.png
# Processed: img\RC04943\page_3.png
# Processed: img\RC04943\page_4.png
# Processed: img\RC04944\page_1.png
# Processed: img\RC04944\page_2.png
# Processed: img\RC04945\page_1.png
# Processed: img\RC04946\page_1.png
# Processed: img\RC04946\page_2.png
# Processed: img\RC04946\page_3.png
# Processed: img\RC04946\page_4.png
# Processed: img\RC04947\page_1.png
# Processed: img\RC04948\page_1.png
# Processed: img\RC04949\page_1.png
# Processed: img\RC04950\page_1.png
# Processed: img\RC04950\page_2.png
# Processed: img\RC04950\page_3.png
# Processed: img\RC04950\page_4.png
# Processed: img\RC04951\page_1.png
# Processed: img\RC04952\page_1.png
# Processed: img\RC04953\page_1.png
# Processed: img\RC04954\page_1.png
# Processed: img\RC04955\page_1.png
# Processed: img\RC04955\page_2.png
# Processed: img\RC04955\page_3.png
# Processed: img\RC04955\page_4.png
# Processed: img\RC04956\page_1.png
# Processed: img\RC04957\page_1.png
# Processed: img\RC04958\page_1.png
# Processed: img\RC04958\page_2.png
# Processed: img\RC04959\page_1.png
# Processed: img\RC04959\page_2.png
# Processed: img\RC04959\page_3.png
# Processed: img\RC04959\page_4.png
# Processed: img\RC04960\page_1.png
# Processed: img\RC04960\page_2.png
# Processed: img\RC04961\page_2.png
# Processed: img\RC04961\page_3.png
# Processed: img\RC04962\page_1.png
# Processed: img\RC04962\page_2.png
# Processed: img\RC04962\page_3.png
# Processed: img\RC04962\page_4.png
# Processed: img\RC04963\page_2.png
# Processed: img\RC04964\page_1.png
# Processed: img\RC04964\page_3.png
# Processed: img\RC04965\page_1.png
# Processed: img\RC04965\page_2.png
# Processed: img\RC04965\page_3.png
# Processed: img\RC04965\page_4.png
# Processed: img\RC04966\page_3.png
# Processed: img\RC04967\page_1.png
# Processed: img\RC04967\page_2.png
# Processed: img\RC04968\page_1.png
# Processed: img\RC04968\page_2.png
# Processed: img\RC04968\page_3.png
# Processed: img\RC04968\page_4.png
# Processed: img\RC04969\page_1.png
# Processed: img\RC04969\page_2.png
# Processed: img\RC04969\page_3.png
# Processed: img\RC04969\page_4.png
# Processed: img\RC04970\page_3.png
# Processed: img\RC04971\page_1.png
# Processed: img\RC04971\page_2.png
# Processed: img\RC04971\page_3.png
# Processed: img\RC04971\page_4.png
# Processed: img\RC04972\page_1.png
# Processed: img\RC04973\page_2.png
# Processed: img\RC04974\page_2.png
# Processed: img\RC04975\page_2.png
# Processed: img\RC04976\page_2.png
# Processed: img\RC04977\page_1.png
# Processed: img\RC05017\page_1.png
# Processed: img\RC05018\page_1.png
# Processed: img\RC05018\page_2.png
# Processed: img\RC05019\page_1.png
# Processed: img\RC05020\page_1.png
# Processed: img\RC05021\page_2.png
# Processed: img\RC05022\page_1.png
# Processed: img\RC05023\page_1.png
# Processed: img\RC05024\page_1.png
# Processed: img\RC05025\page_1.png
# Processed: img\RC05026\page_1.png
# Processed: img\RC05026\page_2.png
# Processed: img\RC05026\page_3.png
# Processed: img\RC05026\page_4.png
# Processed: img\RC05027\page_1.png
# Processed: img\RC05027\page_3.png
# Processed: img\RC05028\page_2.png
# Processed: img\RC05028\page_3.png
# Processed: img\RC05029\page_1.png
# Processed: img\RC05029\page_3.png
# Processed: img\RC05030\page_1.png
# Processed: img\RC05031\page_1.png
# Processed: img\RC05032\page_2.png
# Processed: img\RC05033\page_2.png
# Processed: img\RC05033\page_3.png
# Processed: img\RC05034\page_2.png
# Processed: img\RC05035\page_2.png
# Processed: img\RC05035\page_3.png
# Processed: img\RC05036\page_2.png
# Processed: img\RC05036\page_3.png
# Processed: img\RC05037\page_1.png
# Processed: img\RC05038\page_2.png
# Processed: img\RC05039\page_2.png
# Processed: img\RC05040\page_2.png
# Processed: img\RC05041\page_1.png
# Processed: img\RC05041\page_2.png
# Processed: img\RC05041\page_3.png
# Processed: img\RC05041\page_4.png
# Processed: img\RC05042\page_1.png
# Processed: img\RC05042\page_2.png
# Processed: img\RC05042\page_3.png
# Processed: img\RC05042\page_4.png
# Processed: img\RC05043\page_2.png
# Processed: img\RC05043\page_3.png
# Processed: img\RC05049\page_1.png
# Processed: img\RC05050\page_2.png
# Processed: img\RC05051\page_1.png
# Processed: img\RC05051\page_2.png
# Processed: img\RC05051\page_3.png
# Processed: img\RC05051\page_4.png
# Processed: img\RC05052\page_1.png
# Processed: img\RC05053\page_1.png
# Processed: img\RC05053\page_2.png
# Processed: img\RC05053\page_3.png
# Processed: img\RC05053\page_4.png
# Processed: img\RC05054\page_1.png
# Processed: img\RC05055\page_1.png
# Processed: img\RC05055\page_2.png
# Processed: img\RC05055\page_3.png
# Processed: img\RC05055\page_4.png
# Processed: img\RC05056\page_2.png
# Processed: img\RC05056\page_3.png
# Processed: img\RC05057\page_2.png
# Processed: img\RC05058\page_1.png
# Processed: img\RC05058\page_2.png
# Processed: img\RC05058\page_3.png
# Processed: img\RC05058\page_4.png
# Processed: img\RC05059\page_1.png
# Processed: img\RC05059\page_2.png
# Processed: img\RC05059\page_3.png
# Processed: img\RC05059\page_4.png
# Processed: img\RC05060\page_1.png
# Processed: img\RC05060\page_2.png
# Processed: img\RC05060\page_3.png
# Processed: img\RC05060\page_4.png
# Processed: img\RC05061\page_2.png
# Processed: img\RC05062\page_1.png
# Processed: img\RC05062\page_2.png
# Processed: img\RC05063\page_1.png
# Processed: img\RC05063\page_2.png
# Processed: img\RC05063\page_3.png
# Processed: img\RC05063\page_4.png
# Processed: img\RC05064\page_1.png
# Processed: img\RC05064\page_2.png
# Processed: img\RC05065\page_2.png
# Processed: img\RC05067\page_2.png
# Processed: img\RC05069\page_1.png
# Processed: img\RC05069\page_2.png
# Processed: img\RC05069\page_3.png
# Processed: img\RC05069\page_4.png
# Processed: img\RC05070\page_1.png
# Processed: img\RC05070\page_2.png
# Processed: img\RC05071\page_1.png
# Processed: img\RC05072\page_1.png
# Processed: img\RC05072\page_2.png
# Processed: img\RC05073\page_1.png
# Processed: img\RC05073\page_2.png
# Processed: img\RC05073\page_3.png
# Processed: img\RC05073\page_4.png
# Processed: img\RC05075\page_1.png
# Processed: img\RC05075\page_2.png
# Processed: img\RC05075\page_3.png
# Processed: img\RC05075\page_4.png
# Processed: img\RC05076\page_1.png
# Processed: img\RC05077\page_1.png
# Processed: img\RC05077\page_2.png
# Processed: img\RC05077\page_3.png
# Processed: img\RC05077\page_4.png
# Processed: img\RC05078\page_1.png
# Processed: img\RC05079\page_1.png
# Processed: img\RC05079\page_2.png
# Processed: img\RC05080\page_1.png
# Processed: img\RC05081\page_1.png
# Processed: img\RC05081\page_2.png
# Processed: img\RC05081\page_3.png
# Processed: img\RC05081\page_4.png
# Processed: img\RC05084\page_2.png
# Processed: img\RC05085\page_2.png
# Processed: img\RC05086\page_1.png
# Processed: img\RC05086\page_2.png
# Processed: img\RC05087\page_1.png
# Processed: img\RC05087\page_2.png
# Processed: img\RC05087\page_3.png
# Processed: img\RC05087\page_4.png
# Processed: img\RC05089\page_1.png
# Processed: img\RC05089\page_2.png
# Processed: img\RC05090\page_3.png
# Processed: img\RC05091\page_2.png
# Processed: img\RC05092\page_3.png
# Processed: img\RC05093\page_1.png
# Processed: img\RC05093\page_2.png
# Processed: img\RC05094\page_1.png
# Processed: img\RC05094\page_4.png
# Processed: img\RC05095\page_1.png
# Processed: img\RC05095\page_2.png
# Processed: img\RC05096\page_2.png
# Processed: img\RC05096\page_3.png
# Processed: img\RC05097\page_1.png
# Processed: img\RC05097\page_2.png
# Processed: img\RC05097\page_3.png
# Processed: img\RC05097\page_4.png
# Processed: img\RC05098\page_2.png
# Processed: img\RC05099\page_2.png
# Processed: img\RC05099\page_3.png
# Processed: img\RC05100\page_2.png
# Processed: img\RC05101\page_2.png
# Processed: img\RC05102\page_1.png
# Processed: img\RC05102\page_2.png
# Processed: img\RC05103\page_1.png
# Processed: img\RC05103\page_2.png
# Processed: img\RC05103\page_3.png
# Processed: img\RC05103\page_4.png
# Processed: img\RC05104\page_2.png
# Processed: img\RC05104\page_3.png
# Processed: img\RC05105\page_2.png
# Processed: img\RC05105\page_3.png
# Processed: img\RC05106\page_1.png
# Processed: img\RC05106\page_2.png
# Processed: img\RC05106\page_3.png
# Processed: img\RC05106\page_4.png
# Processed: img\RC05107\page_2.png
# Processed: img\RC05108\page_2.png
# Processed: img\RC05109\page_1.png
# Processed: img\RC05109\page_2.png
# Processed: img\RC05110\page_1.png
# Processed: img\RC05110\page_3.png
# Processed: img\RC05110\page_4.png
# Processed: img\RC05111\page_1.png
# Processed: img\RC05111\page_2.png
# Processed: img\RC05111\page_3.png
# Processed: img\RC05111\page_4.png
# Processed: img\RC05112\page_2.png
# Processed: img\RC05113\page_1.png
# Processed: img\RC05114\page_1.png
# Processed: img\RC05115\page_1.png
# Processed: img\RC05116\page_1.png
# Processed: img\RC05117\page_1.png
# Processed: img\RC05117\page_2.png
# Processed: img\RC05117\page_3.png
# Processed: img\RC05117\page_4.png
# Processed: img\RC05118\page_2.png
# Processed: img\RC05119\page_1.png
# Processed: img\RC05119\page_2.png
# Processed: img\RC05119\page_3.png
# Processed: img\RC05119\page_4.png
# Processed: img\RC05119\page_5.png
# Processed: img\RC05119\page_6.png
# Processed: img\RC05120\page_2.png
# Processed: img\RC05121\page_1.png
# Processed: img\RC05122\page_1.png
# Processed: img\RC05122\page_2.png
# Processed: img\RC05122\page_3.png
# Processed: img\RC05122\page_4.png
# Processed: img\RC05123\page_2.png
# Processed: img\RC05124\page_1.png
# Processed: img\RC05124\page_2.png
# Processed: img\RC05125\page_2.png
# Processed: img\RC05126\page_1.png
# Processed: img\RC05127\page_1.png
# Processed: img\RC05128\page_1.png
# Processed: img\RC05128\page_2.png
# Processed: img\RC05129\page_2.png
# Processed: img\RC05129\page_3.png
# Processed: img\RC05130\page_1.png
# Processed: img\RC05130\page_2.png
# Processed: img\RC05130\page_3.png
# Processed: img\RC05130\page_4.png
# Processed: img\RC05131\page_2.png
# Processed: img\RC05132\page_1.png
# Processed: img\RC05132\page_2.png
# Processed: img\RC05132\page_3.png
# Processed: img\RC05132\page_4.png
# Processed: img\RC05133\page_1.png
# Processed: img\RC05134\page_2.png
# Processed: img\RC05135\page_2.png
# Processed: img\RC05135\page_3.png
# Processed: img\RC05136\page_2.png
# Processed: img\RC05137\page_2.png
# Processed: img\RC05138\page_1.png
# Processed: img\RC05139\page_1.png
# Processed: img\RC05139\page_2.png
# Processed: img\RC05139\page_3.png
# Processed: img\RC05139\page_4.png
# Processed: img\RC05140\page_1.png
# Processed: img\RC05141\page_1.png
# Processed: img\RC05142\page_1.png
# Processed: img\RC05143\page_1.png
# Processed: img\RC05143\page_2.png
# Processed: img\RC05143\page_3.png
# Processed: img\RC05144\page_1.png
# Processed: img\RC05145\page_1.png
# Processed: img\RC05146\page_1.png
# Processed: img\RC05147\page_1.png
# Processed: img\RC05148\page_1.png
# Processed: img\RC05148\page_2.png
# Processed: img\RC05148\page_3.png
# Processed: img\RC05148\page_4.png
# Processed: img\RC05149\page_1.png
# Processed: img\RC05150\page_1.png
# Processed: img\RC05151\page_1.png
# Processed: img\RC05151\page_2.png
# Processed: img\RC05151\page_3.png
# Processed: img\RC05151\page_4.png
# Processed: img\RC05152\page_1.png
# Processed: img\RC05153\page_1.png
# Processed: img\RC05154\page_1.png
# Processed: img\RC05155\page_1.png
# Processed: img\RC05155\page_2.png
# Processed: img\RC05156\page_1.png
# Processed: img\RC05156\page_2.png
# Processed: img\RC05156\page_3.png
# Processed: img\RC05157\page_1.png
# Processed: img\RC05158\page_2.png
# Processed: img\RC05159\page_1.png
# Processed: img\RC05160\page_1.png
# Processed: img\RC05160\page_2.png
# Processed: img\RC05160\page_3.png
# Processed: img\RC05160\page_4.png
# Processed: img\RC05161\page_1.png
# Processed: img\RC05207\page_1.png
# Processed: img\RC05208\page_2.png
# Processed: img\RC05209\page_1.png
# Processed: img\RC05209\page_2.png
# Processed: img\RC05209\page_3.png
# Processed: img\RC05209\page_4.png
# Processed: img\RC05210\page_1.png
# Processed: img\RC05211\page_1.png
# Processed: img\RC05212\page_1.png
# Processed: img\RC05212\page_2.png
# Processed: img\RC05212\page_3.png
# Processed: img\RC05212\page_4.png
# Processed: img\RC05213\page_2.png
# Processed: img\RC05214\page_2.png
# Processed: img\RC05215\page_2.png
# Processed: img\RC05216\page_1.png
# Processed: img\RC05217\page_2.png
# Processed: img\RC05218\page_1.png
# Processed: img\RC05219\page_1.png
# Processed: img\RC05219\page_2.png
# Processed: img\RC05219\page_3.png
# Processed: img\RC05219\page_4.png
# Processed: img\RC05220\page_2.png
# Processed: img\RC05221\page_2.png
# Processed: img\RC05222\page_2.png
# Processed: img\RC05223\page_1.png
# Processed: img\RC05223\page_2.png
# Processed: img\RC05224\page_3.png
# Processed: img\RC05225\page_1.png
# Processed: img\RC05225\page_2.png
# Processed: img\RC05225\page_3.png
# Processed: img\RC05225\page_4.png
# Processed: img\RC05226\page_1.png
# Processed: img\RC05226\page_2.png
# Processed: img\RC05227\page_1.png
# Processed: img\RC05228\page_3.png
# Processed: img\RC05229\page_1.png
# Processed: img\RC05229\page_2.png
# Processed: img\RC05229\page_3.png
# Processed: img\RC05229\page_4.png
# Processed: img\RC05230\page_1.png
# Processed: img\RC05230\page_2.png
# Processed: img\RC05230\page_3.png
# Processed: img\RC05230\page_4.png
# Processed: img\RC05231\page_1.png
# Processed: img\RC05232\page_1.png
# Processed: img\RC05232\page_2.png
# Processed: img\RC05232\page_3.png
# Processed: img\RC05232\page_4.png
# Processed: img\RC05233\page_1.png
# Processed: img\RC05233\page_3.png
# Processed: img\RC05234\page_3.png
# Processed: img\RC05235\page_2.png
# Processed: img\RC05236\page_1.png
# Processed: img\RC05237\page_2.png
# Processed: img\RC05238\page_2.png
# Processed: img\RC05239\page_1.png
# Processed: img\RC05240\page_1.png
# Processed: img\RC05241\page_1.png
# Processed: img\RC05242\page_2.png
# Processed: img\RC05243\page_1.png
# Processed: img\RC05244\page_1.png
# Processed: img\RC05245\page_1.png
# Processed: img\RC05246\page_1.png
# Processed: img\RC05247\page_1.png
# Processed: img\RC05248\page_2.png
# Processed: img\RC05249\page_1.png
# Processed: img\RC05251\page_2.png
# Processed: img\RC05252\page_2.png
# Processed: img\RC05253\page_1.png
# Processed: img\RC05254\page_2.png
# Processed: img\RC05255\page_3.png
# Processed: img\RC05256\page_2.png
# Processed: img\RC05277\page_1.png
# Processed: img\RC05716\page_1.png
# Processing complete. All images saved in: output_2
